# %%
import numpy as np
import pandas as pd
import spacy
import nltk
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set()
# Out:
# C:\Users\iman_\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
nlp = spacy.load('en_core_web_lg')

# %%
df = pd.read_csv('train.csv')

# %%
df.head(20)
# Out:
#     sentiment                                            message  tweetid
# 0           1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1           1  It's not like we lack evidence of anthropogeni...   126103
# 2           2  RT @RawStory: Researchers say we have three ye...   698562
# 3           1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4           1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# 5           1  Worth a read whether you do or don't believe i...   425577
# 6           1  RT @thenation: Mike Pence doesn’t believe in g...   294933
# 7           1  RT @makeandmendlife: Six big things we can ALL...   992717
# 8           1  @AceofSpadesHQ My 8yo nephew is inconsolable. ...   664510
# 9           1  RT @paigetweedy: no offense… but like… how do ...   260471
# 10          1  RT @StephenSchlegel: she's thinking about how ...   295793
# 11          1  I do hope people who are vocal about climate c...   763719
# 12          2  RT @tveitdal: We only have a 5 percent chance ...   454673
# 13          1  RT @Alifaith55: Oh. My. God.\n\nTrump's Govern...    41161
# 14          2  Fossil fuel giant ExxonMobil ‘misled’ the publ...   658092
# 15          1  RT @GlblCtzn: 'I don't wanna live forever – an...   319524
# 16          1  RT @jackholmes0: Issues scrubbed from https://...   698009
# 17          1  RT @patagonia: If our elected leaders fail to ...   490604
# 18          1  RT @SenSanders: We have a president-elect who ...   228658
# 19          0  Calum: *tweets abt reunitingish w the cast*\n-...   547924

# %%
df['message'][12]
# Out:
# 'RT @tveitdal: We only have a 5 percent chance of avoiding ‘dangerous’ global warming, a study finds https://t.co/xUBTqNxhkK https://t.co/of…'

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15819 entries, 0 to 15818
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  15819 non-null  int64
#  1   message    15819 non-null  object
#  2   tweetid    15819 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 370.9+ KB

# %%
df.describe(include='all')
# Out:
#            sentiment                                            message  \
# count   15819.000000                                              15819
# unique           NaN                                              14229
# top              NaN  RT @StephenSchlegel: she's thinking about how ...
# freq             NaN                                                307
# mean        0.917504                                                NaN
# std         0.836537                                                NaN
# min        -1.000000                                                NaN
# 25%         1.000000                                                NaN
# 50%         1.000000                                                NaN
# 75%         1.000000                                                NaN
# max         2.000000                                                NaN
#
#               tweetid
# count    15819.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    501719.433656
# std     289045.983132
# min          6.000000
# 25%     253207.500000
# 50%     502291.000000
# 75%     753769.000000
# max     999888.000000

# %%
###def clean_text(text):
    #text = re.sub(r'@[A-za-z0-9]+', '', text) 
    #text = re.sub(r'#', '', text)
    #text = re.sub(r'RT[\s]+', '', text)
   # text = re.sub(r'https?:\/\/\S+', '', text)
   # text = text.replace(':', '')
   # return text

# %%
#df['Tweets'] = df['message'].apply(clean_text)

# %%
df['sentiment'].value_counts().plot(kind='bar')
## judging from this, sentiment analysis 1 makes up most of the

# %% [markdown]
# # Examining Twitter Mentions

# %%
df['Split_tweets'] = [i.split() for i in df['message']]

# %%
df['mentions'] = df.message.str.findall(r'(?<![@\w])@(\w{1,25})').apply(','.join)

# %%
df['mentions'].nunique()
# Out:
# 6902

# %%
df['mentions'].value_counts()[1:20].plot(kind='bar')
plt.show()

# %%
df[df['mentions'] == 'BernieSanders']['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from Sanders mentions')
plt.show()

# %%
df[df['mentions'] == 'SenSanders']['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from Sanders mentions')
plt.show()

# %%
df[df['mentions'] == 'realDonaldTrump']['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from Trump mentions')
plt.show()

# %%
df[df['mentions'] == 'StephenSchlegel']['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from StephenSchlegel mentions')
plt.show()

# %% [markdown]
# From this analysis of the top mentions, we can tell that the type of mentions affect sentiment thus we can keep our @user mentions

# %%
df[df['mentions'] == 'nytimes']['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from nytimes')
plt.show()

# %% [markdown]
# Looking at the distribution of a reputable source like NY Times, we can see that most sentiment is directed to real news sentiment thus we can assume that most mentions with a Named Entity will fall into this sentiment category.

# %% [markdown]
# ## Find all hashtags

# %%
def hashtag_extractor(x):
    hashtags = []
    for i in x:
        ht = re.findall(r'#(\w+)', i)
        hashtags.append(ht)
    return hashtags

# %%
HT_neg = hashtag_extractor(df['message'][df['sentiment'] == -1])
HT_neutral = hashtag_extractor(df['message'][df['sentiment'] == 0])
HT_pos = hashtag_extractor(df['message'][df['sentiment'] == 1])
HT_news = hashtag_extractor(df['message'][df['sentiment'] == 2])

HT_neg = sum(HT_neg, [])
HT_neutral = sum(HT_neutral, [])
HT_pos = sum(HT_pos, [])
HT_news = sum(HT_news, [])

# %%
HT_neg
# Out:
# ['NoMoreSCAMS',
#  'NoMoreDEMOCRATS',
#  'DrainTheSwamp',
#  'fakenews',
#  'myth',
#  'maga',
#  'stepfoÃ',
#  'OpChemtrails',
#  'earthday',
#  'miamibeachbowl',
#  'liberals',
#  'LiberalLogic',
#  'Trump',
#  'QandA',
#  'Snow',
#  'Egypt',
#  'Trump',
#  'ClimateChange',
#  'MarchforBabies',
#  'lies',
#  'Economy',
#  'National',
#  'LondonAttacks',
#  'StandUpForScience',
#  'CashinIn',
#  'ClimateScam',
#  'GreenScam',
#  'TeaParty',
#  'tcot',
#  'PJNet',
#  'OpChemtrails',
#  'blizzard2017',
#  'OpChemtrails',
#  'MAGA',
#  'TrumpTrain',
#  'Dobbs',
#  'feedly',
#  'ScienceCelebs',
#  'libtards',
#  'UnicornsAreReal',
#  'Snowflakes',
#  'WhyWeMustImpeachTrumpIn7Words',
#  'PresidentTrump',
#  'Day1Promises',
#  'Obamacare',
#  'MAGA',
#  'BullShit',
#  'FakeScience',
#  'Eugenics',
#  'Science',
#  'TaxDay',
#  'Trump',
#  'sad',
#  'climate',
#  'Eco',
#  'Green',
#  'Trump',
#  'QandA',
#  'planetx',
#  'Trump',
#  'ParisAgreement',
#  'GoreEffect',
#  'a',
#  'STFU',
#  'MAGA',
#  'peoplesclimatemarch',
#  'UnitedNations',
#  'CO2',
#  'NewVettingQuestions',
#  'MAGA',
#  'IAmAClim',
#  'SnakeOilSales',
#  'liars',
#  'fakenews',
#  'MichaelCreighton',
#  'environmental',
#  'climate',
#  'Arctic',
#  'BillNye',
#  'CNN',
#  'ClimateÃ',
#  'Trump',
#  'WhatILearnedToday',
#  'Hann',
#  'IfOnlyTheEarthCouldSpeak',
#  'climatechange',
#  'ausecon',
#  'ausbiz',
#  'auspol',
#  'climate',
#  'ObamaLega',
#  'AmericaFirst',
#  'ooc',
#  'PruittS',
#  'Fact',
#  'MarchAgainstSharia',
#  'climatemarch',
#  'climatemarch',
#  'buffoons',
#  'benghazi',
#  'QandA',
#  'CNN',
#  'CNNisISIS',
#  'Trump',
#  'DrainTheSwamp',
#  'TrumpRiot',
#  'MAGA',
#  'LiberalHysteria',
#  'tcot',
#  'p2',
#  'leowatch',
#  'climate',
#  'climate',
#  'ClimateScam',
#  'PJNet',
#  'Hypocrite',
#  'mag',
#  'corr',
#  'toronto',
#  'chemtrails',
#  'geoengineering',
#  'srm',
#  'StepsToReverseClimateChange',
#  'MAGA',
#  'ma4t',
#  'climatechange',
#  'BlameRussia',
#  'RussiaGate',
#  'climate',
#  'PussyGeneration',
#  'ClimateGate',
#  'Solar',
#  'A',
#  'algore',
#  'climatechange',
#  'SnowStorm',
#  'FakeNews',
#  'globalwarming',
#  'EPA',
#  'LondonAttacks',
#  'ObamaLegacy',
#  'ParisAgreement',
#  'globalwarming',
#  'climatechange',
#  'hoax',
#  'fraud',
#  'fail',
#  'lie',
#  'WakeUpAmerica',
#  'Glaciation',
#  'USFA',
#  'tcot',
#  'ccot',
#  'gop',
#  'maga',
#  'MAGA',
#  'NAD',
#  'LondonBridge',
#  'CNN',
#  'CarbonTax',
#  'ROCKYMOUNTAINS',
#  'OpChemtr',
#  'FakeGlobal',
#  'GlobalWarming',
#  'ElectricCars',
#  'ableg',
#  'IPCC',
#  'Covfefe',
#  'climate',
#  'OpChemtrails',
#  'SRM',
#  'climatechange',
#  'environment',
#  'ParisAgr',
#  'marchforscience',
#  'fakenews',
#  'feedly',
#  'DailyCrowder',
#  'Trudeau',
#  'SenateHearing',
#  'Tillerson',
#  'EndClimateHysteria',
#  'Listen',
#  'OpChemPBA',
#  'SAI',
#  'ClimateScam',
#  'climate',
#  'tcot',
#  'p2',
#  'Climatechangehoax',
#  'Maga',
#  'Election2016',
#  'climatechange',
#  'JunkScience',
#  'RedNationRising',
#  'GreatAmerica',
#  'MAGA',
#  'Period',
#  'ParisAgreement',
#  'ClimateChangeIn5Words',
#  'iamright',
#  'PresidentTrump',
#  'chemtrails',
#  'antisemitic',
#  'MAGA',
#  'POTUS',
#  'TruePundit',
#  'EPA',
#  'globalwarming',
#  'Tucker',
#  'ParisAgreement',
#  'climate',
#  'trumpriot',
#  't',
#  'islamicState',
#  'tcoÃ',
#  'Jan20',
#  'JustAsking',
#  'Science',
#  'MAGA',
#  'TRUMP',
#  'G20Summit',
#  'ConfessYourUnpopularOpinion',
#  'science',
#  'londonbridge',
#  'MAGA',
#  'ClimateChange',
#  'GlobalWarming',
#  'Hoax',
#  'PeoplesClimateMarch',
#  'ThingsTrumpThinksAreOverrated',
#  'climatemarch',
#  'NoSurpriseHere',
#  'globalcooling',
#  'climate',
#  'PoliticallyReactive',
#  'cdnpoli',
#  'media',
#  'Brrrr',
#  'hypocrisy',
#  'Agenda2030']

# %%
p = nltk.FreqDist(HT_neg)
p
# Out:
# FreqDist({'MAGA': 11, 'climate': 10, 'Trump': 7, 'climatechange': 6, 'OpChemtrails': 4, 'tcot': 4, 'ParisAgreement': 4, 'fakenews': 3, 'QandA': 3, 'ClimateScam': 3, ...})

# %%
p = nltk.FreqDist(HT_neg)
d = pd.DataFrame({'Hashtag': list(p.keys()), 'Count': list(p.values())})

d
# Out:
#              Hashtag  Count
# 0        NoMoreSCAMS      1
# 1    NoMoreDEMOCRATS      1
# 2      DrainTheSwamp      2
# 3           fakenews      3
# 4               myth      1
# ..               ...    ...
# 173          cdnpoli      1
# 174            media      1
# 175            Brrrr      1
# 176        hypocrisy      1
# 177       Agenda2030      1
#
# [178 rows x 2 columns]

# %%
p = nltk.FreqDist(HT_neg)
d = pd.DataFrame({'Hashtag': list(p.keys()), 'Count': list(p.values())})
d = d.nlargest(columns = 'Count', n = 15)
plt.figure(figsize=(18, 8))
ax = sns.barplot(data=d, x = 'Hashtag', y = 'Count')
plt.tight_layout()
plt.show()

# %%
p = nltk.FreqDist(HT_neutral)
d = pd.DataFrame({'Hashtag': list(p.keys()), 'Count': list(p.values())})
d = d.nlargest(columns = 'Count', n = 15)
plt.figure(figsize=(18, 8))
ax = sns.barplot(data=d, x = 'Hashtag', y = 'Count')
plt.tight_layout()
plt.show()

# %%
p = nltk.FreqDist(HT_pos)
d = pd.DataFrame({'Hashtag': list(p.keys()), 'Count': list(p.values())})
d = d.nlargest(columns = 'Count', n = 15)
plt.figure(figsize=(18, 8))
ax = sns.barplot(data=d, x = 'Hashtag', y = 'Count')
plt.tight_layout()
plt.show()

# %%
p = nltk.FreqDist(HT_news)
d = pd.DataFrame({'Hashtag': list(p.keys()), 'Count': list(p.values())})
d = d.nlargest(columns = 'Count', n = 15)
plt.figure(figsize=(18, 8))
ax = sns.barplot(data=d, x = 'Hashtag', y = 'Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# From our hashtags, we can tell that climate once again is spread out throughout all sentiments and is the most frequest apart from negative sentiment

# %% [markdown]
# ## Study Subjectivity and Polarity

# %%
def subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
from textblob import TextBlob

# %%
df['Subjectivity'] = df['message'].apply(subjectivity)
df['Polarity'] = df["message"].apply(polarity)

# %%
df.head(50)
# Out:
#     sentiment                                            message  tweetid  \
# 0           1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1           1  It's not like we lack evidence of anthropogeni...   126103
# 2           2  RT @RawStory: Researchers say we have three ye...   698562
# 3           1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4           1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# 5           1  Worth a read whether you do or don't believe i...   425577
# 6           1  RT @thenation: Mike Pence doesn’t believe in g...   294933
# 7           1  RT @makeandmendlife: Six big things we can ALL...   992717
# 8           1  @AceofSpadesHQ My 8yo nephew is inconsolable. ...   664510
# 9           1  RT @paigetweedy: no offense… but like… how do ...   260471
# 10          1  RT @StephenSchlegel: she's thinking about how ...   295793
# 11          1  I do hope people who are vocal about climate c...   763719
# 12          2  RT @tveitdal: We only have a 5 percent chance ...   454673
# 13          1  RT @Alifaith55: Oh. My. God.\n\nTrump's Govern...    41161
# 14          2  Fossil fuel giant ExxonMobil ‘misled’ the publ...   658092
# 15          1  RT @GlblCtzn: 'I don't wanna live forever – an...   319524
# 16          1  RT @jackholmes0: Issues scrubbed from https://...   698009
# 17          1  RT @patagonia: If our elected leaders fail to ...   490604
# 18          1  RT @SenSanders: We have a president-elect who ...   228658
# 19          0  Calum: *tweets abt reunitingish w the cast*\n-...   547924
# 20          1  RT @c40cities: 46 C40 Mayors, representing 250...   625014
# 21          1  RT @World_Wildlife: How climate change impacts...   690605
# 22          0  we also met this guy, he let us in on some tru...    67545
# 23          1  https://t.co/KyNIBjmDk5\nScientists say climat...   567842
# 24          1  RT @TammyGrubb: Obama raises climate change. Y...   684492
# 25          1  I hate to say this, but *mental* health will b...   438578
# 26          2  Bangladesh confronting climate change head on ...   365291
# 27          1  Hey There! Michael's vetted and approved marke...   387685
# 28         -1  Sally Kohn’s latest evidence of climate change...   355491
# 29          1  RT @StarTalkRadio: First: The public understan...   354015
# 30          0  @Jnp_Ftw are these the same scientists that de...   365051
# 31          1  RT @Honey17011: A guide to global warming, Par...   432987
# 32          2  RT @latimes: Atmospheric rivers fueled by clim...   143471
# 33          1       Denying climate change ignores basic science    11622
# 34          1  BGR ~ China practically says Trump lied about ...   497877
# 35          1  RT @BernieSanders: #ImVotingBecause the future...   817108
# 36          2  RT @Independent: Trump's team removed climate ...   526603
# 37          1  RT @DeboraheHart: Toxic soils, aquifers, vast ...   362709
# 38          1  RT @BettyBowers: America: Where climate change...   569142
# 39          0  We’ ve dealt with simple issues like climate c...   403368
# 40          1  RT @ForAmerica: They protested in support of c...   303380
# 41          2  2050 climate targets: nations are playing the ...     8984
# 42          1  RT @thedailybeast: Trump's climate change deni...   765266
# 43          0  RT @andrewsharp: Win probability is bullshit m...   326916
# 44          2  RT @washingtonpost: The Alaskan tundra is fill...   905639
# 45          2  RT @TheTorontoSun: From @sunlorrie: Indian env...   741568
# 46         -1  @realDonaldTrump Carbon Tax is a Globalist ide...    61141
# 47          1  Will anyone who supports Trumps view of climat...   344320
# 48         -1  RT @SteveSGoddard: We had winds close to 100 M...   719523
# 49          2  RT @Starbuck: World food supplies at risk as #...   499888
#
#                                          Split_tweets  \
# 0   [PolySciMajor, EPA, chief, doesn't, think, car...
# 1   [It's, not, like, we, lack, evidence, of, anth...
# 2   [RT, @RawStory:, Researchers, say, we, have, t...
# 3   [#TodayinMaker#, WIRED, :, 2016, was, a, pivot...
# 4   [RT, @SoyNovioDeTodas:, It's, 2016,, and, a, r...
# 5   [Worth, a, read, whether, you, do, or, don't, ...
# 6   [RT, @thenation:, Mike, Pence, doesn’t, believ...
# 7   [RT, @makeandmendlife:, Six, big, things, we, ...
# 8   [@AceofSpadesHQ, My, 8yo, nephew, is, inconsol...
# 9   [RT, @paigetweedy:, no, offense…, but, like…, ...
# 10  [RT, @StephenSchlegel:, she's, thinking, about...
# 11  [I, do, hope, people, who, are, vocal, about, ...
# 12  [RT, @tveitdal:, We, only, have, a, 5, percent...
# 13  [RT, @Alifaith55:, Oh., My., God., Trump's, Go...
# 14  [Fossil, fuel, giant, ExxonMobil, ‘misled’, th...
# 15  [RT, @GlblCtzn:, 'I, don't, wanna, live, forev...
# 16  [RT, @jackholmes0:, Issues, scrubbed, from, ht...
# 17  [RT, @patagonia:, If, our, elected, leaders, f...
# 18  [RT, @SenSanders:, We, have, a, president-elec...
# 19  [Calum:, *tweets, abt, reunitingish, w, the, c...
# 20  [RT, @c40cities:, 46, C40, Mayors,, representi...
# 21  [RT, @World_Wildlife:, How, climate, change, i...
# 22  [we, also, met, this, guy,, he, let, us, in, o...
# 23  [https://t.co/KyNIBjmDk5, Scientists, say, cli...
# 24  [RT, @TammyGrubb:, Obama, raises, climate, cha...
# 25  [I, hate, to, say, this,, but, *mental*, healt...
# 26  [Bangladesh, confronting, climate, change, hea...
# 27  [Hey, There!, Michael's, vetted, and, approved...
# 28  [Sally, Kohn’s, latest, evidence, of, climate,...
# 29  [RT, @StarTalkRadio:, First:, The, public, und...
# 30  [@Jnp_Ftw, are, these, the, same, scientists, ...
# 31  [RT, @Honey17011:, A, guide, to, global, warmi...
# 32  [RT, @latimes:, Atmospheric, rivers, fueled, b...
# 33  [Denying, climate, change, ignores, basic, sci...
# 34  [BGR, ~, China, practically, says, Trump, lied...
# 35  [RT, @BernieSanders:, #ImVotingBecause, the, f...
# 36  [RT, @Independent:, Trump's, team, removed, cl...
# 37  [RT, @DeboraheHart:, Toxic, soils,, aquifers,,...
# 38  [RT, @BettyBowers:, America:, Where, climate, ...
# 39  [We’, ve, dealt, with, simple, issues, like, c...
# 40  [RT, @ForAmerica:, They, protested, in, suppor...
# 41  [2050, climate, targets:, nations, are, playin...
# 42  [RT, @thedailybeast:, Trump's, climate, change...
# 43  [RT, @andrewsharp:, Win, probability, is, bull...
# 44  [RT, @washingtonpost:, The, Alaskan, tundra, i...
# 45  [RT, @TheTorontoSun:, From, @sunlorrie:, India...
# 46  [@realDonaldTrump, Carbon, Tax, is, a, Globali...
# 47  [Will, anyone, who, supports, Trumps, view, of...
# 48  [RT, @SteveSGoddard:, We, had, winds, close, t...
# 49  [RT, @Starbuck:, World, food, supplies, at, ri...
#
#                               mentions                          hashtags  \
# 0                             mashable
# 1
# 2                             RawStory
# 3                                                           TodayinMaker
# 4                      SoyNovioDeTodas                     ElectionNight
# 5
# 6                            thenation
# 7                      makeandmendlife
# 8                        AceofSpadesHQ
# 9                          paigetweedy
# 10                     StephenSchlegel
# 11                          GoodEnergy
# 12                            tveitdal
# 13                          Alifaith55                      climatemarch
# 14
# 15    GlblCtzn,taylorswift13,zaynmalik
# 16                         jackholmes0
# 17                           patagonia
# 18                          SenSanders
# 19
# 20                           c40cities                     SaveOurPlanet
# 21                      World_Wildlife            COP22,EarthToMarrakech
# 22
# 23                                                              climateÃ
# 24                          TammyGrubb                          ObamaUNC
# 25
# 26
# 27                                                               cdnpoli
# 28                         twitchyteam
# 29  StarTalkRadio,CoryBooker,neiltyson                       JohnHoldren
# 30                             Jnp_Ftw
# 31                          Honey17011  DemForce,TheResistance,UniteBlue
# 32                             latimes
# 33
# 34
# 35                       BernieSanders                   ImVotingBecause
# 36                         Independent
# 37                        DeboraheHart
# 38                         BettyBowers
# 39                                                                 qanda
# 40                          ForAmerica                       WomansMarch
# 41                     ConversationEDU
# 42                       thedailybeast
# 43                         andrewsharp
# 44                      washingtonpost
# 45             TheTorontoSun,sunlorrie
# 46                     realDonaldTrump
# 47                                                        Resist,Impeach
# 48                       SteveSGoddard
# 49                            Starbuck                           climate
#
#     Subjectivity  Polarity
# 0       0.166667  0.083333
# 1       0.000000  0.000000
# 2       0.600000 -0.300000
# 3       0.800000  0.500000
# 4       0.000000  0.000000
# 5       0.100000  0.300000
# 6       0.000000  0.000000
# 7       0.100000  0.000000
# 8       0.150000  0.150000
# 9       0.000000  0.000000
# 10      0.000000  0.000000
# 11      0.000000  0.000000
# 12      0.633333 -0.200000
# 13      0.000000  0.000000
# 14      0.533333  0.000000
# 15      0.500000  0.136364
# 16      0.000000  0.000000
# 17      0.516667 -0.100000
# 18      0.000000  0.000000
# 19      0.000000  0.000000
# 20      0.000000  0.000000
# 21      0.000000  0.000000
# 22      0.583333  0.416667
# 23      0.625000  0.000000
# 24      0.500000  0.500000
# 25      0.600000 -0.162500
# 26      0.000000  0.000000
# 27      0.000000  0.000000
# 28      0.510714  0.298214
# 29      0.300000  0.250000
# 30      0.125000  0.000000
# 31      0.000000  0.000000
# 32      0.200000  0.050000
# 33      0.125000  0.000000
# 34      0.000000  0.000000
# 35      0.125000  0.000000
# 36      0.062500  0.000000
# 37      0.333333 -0.133333
# 38      0.644444  0.450000
# 39      0.378571 -0.150000
# 40      0.000000  0.000000
# 41      0.266667 -0.150000
# 42      0.000000  0.000000
# 43      0.233333  0.333333
# 44      0.000000  0.000000
# 45      0.500000  0.300000
# 46      0.200000  0.100000
# 47      0.000000  0.000000
# 48      0.000000  0.000000
# 49      0.000000  0.000000

# %%
df[df['Subjectivity'] >=0.5]['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from Subjectivity threshold of 0.5')
plt.show()

# %%
df[df['Subjectivity'] <=0.5]['sentiment'].value_counts().plot(kind='bar')
plt.xlabel('sentiment')
plt.ylabel('Counts')
plt.title('Sentiment from Subjectivity threshold of 0.5')
plt.show()

# %% [markdown]
# from this we can deduce that Subjectivity measure doesnt play a major role in being a good predictor of classifying sentiment thus it may not be an important feature. We will test again for it after preprocessing and cleaning the data

# %% [markdown]
# ## Visualize Words and Word Frequency

# %%
from wordcloud import WordCloud

# %%
allwords = ''.join([twts for twts in df['message']])

# %%
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

# %%
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# From the uncleaned data we can see there are a lot of hyperlinks. These might be of interest if we can find what type of website they lead to or we could just drop it. We can also see climate, change, and global warming are well represented since our sentiment is based on that. We can also see there is some political influence as stated above in climate change sentiment.

# %%
## Lets visualize the words that appear as oer sentiment

# %%
allwords_sent_neg = ''.join([twts for twts in df['message'][df['sentiment'] == -1]])

# %%
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords_sent_neg)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# From this we can see that there are some very negative sentiment words

# %%
allwords_sent_neutral = ''.join([twts for twts in df['message'][df['sentiment'] == 0]])

# %%
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords_sent_neutral)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
allwords_sent_pro = ''.join([twts for twts in df['message'][df['sentiment'] == 1]])

# %%
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords_sent_pro)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
allwords_sent_news = ''.join([twts for twts in df['message'][df['sentiment'] == 2]])

# %%
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords_sent_news)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# A few interesting observations after visualising the word frequency as per sentiment.
#
# Global warming appears a lot in neutral and negative sentiiment but does not appear as much in positive sentiment
#
# Climate Change is consistent throughout all sentiments. Maybe we could use ngrams of 3 to get more context of what exact tone is being suggested when the word climate change is present
#
# We can see that in News related sentiment, hyperlinks are present a lot.
#
# Overall, we can see a combination of words are more influential in the data than just single observed words!

# %% [markdown]
# ### Check Missing values, Duplicates and Empty Tweets

# %%
df.iloc[:, :3].isnull().sum() ## no null values
# Out:
# sentiment    0
# message      0
# tweetid      0
# dtype: int64

# %%
## detect and remove empty strings
blanks = []
#(returns index, label, review, text)
for i, lb, rv in df.iloc[:, :2].itertuples():
    if rv.isspace():
        blanks.append(i)
### no missing values

# %%
df[df['message'].duplicated()]
## we can see there are a lot of duplicated tweets. We need to remove them
# Out:
#        sentiment                                            message  tweetid  \
# 51             1  RT @StephenSchlegel: she's thinking about how ...   785499
# 70             1  RT @kelkulus: Irony: Florida, a state in dange...   857540
# 98             1  RT @StephenSchlegel: she's thinking about how ...   603318
# 112            1  RT @SenSanders: We have a president-elect who ...   664093
# 122            1  RT @StephenSchlegel: she's thinking about how ...    97375
# ...          ...                                                ...      ...
# 15781          1  RT @StephenSchlegel: she's thinking about how ...   869993
# 15799          1  RT @SethMacFarlane: HRC proposes installing ha...    52528
# 15801          1  RT @SenSanders: On virtually every major issue...   331127
# 15811          1  RT @StephenSchlegel: she's thinking about how ...   426353
# 15815          2  RT @washingtonpost: How climate change could b...    17856
#
#                                             Split_tweets         mentions  \
# 51     [RT, @StephenSchlegel:, she's, thinking, about...  StephenSchlegel
# 70     [RT, @kelkulus:, Irony:, Florida,, a, state, i...         kelkulus
# 98     [RT, @StephenSchlegel:, she's, thinking, about...  StephenSchlegel
# 112    [RT, @SenSanders:, We, have, a, president-elec...       SenSanders
# 122    [RT, @StephenSchlegel:, she's, thinking, about...  StephenSchlegel
# ...                                                  ...              ...
# 15781  [RT, @StephenSchlegel:, she's, thinking, about...  StephenSchlegel
# 15799  [RT, @SethMacFarlane:, HRC, proposes, installi...   SethMacFarlane
# 15801  [RT, @SenSanders:, On, virtually, every, major...       SenSanders
# 15811  [RT, @StephenSchlegel:, she's, thinking, about...  StephenSchlegel
# 15815  [RT, @washingtonpost:, How, climate, change, c...   washingtonpost
#
#       hashtags  Subjectivity  Polarity
# 51                     0.000  0.000000
# 70                     0.375 -0.125000
# 98                     0.000  0.000000
# 112                    0.000  0.000000
# 122                    0.000  0.000000
# ...        ...           ...       ...
# 15781                  0.000  0.000000
# 15799                  0.250  0.041667
# 15801                  0.500  0.062500
# 15811                  0.000  0.000000
# 15815                  0.000  0.000000
#
# [1590 rows x 8 columns]

# %%
## remove duplicates
df.drop_duplicates(['message'], keep = 'first', inplace = True)

# %%
df['message'][3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66ca18c6bcfa> in <module>
# ----> 1 df['message'][3]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## PreProcessing and Cleaning the DATA
